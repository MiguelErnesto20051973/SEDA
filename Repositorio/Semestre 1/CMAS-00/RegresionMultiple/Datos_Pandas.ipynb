# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_excel('/content/drive/My Drive/RegresionMultiple/Prob_Reg_Mul.xlsx')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(df)
# Out:
#     identificador  part.almz.escl  ...  region  serv.bas.compl
# 0            1044            73.8  ...       B              SI
# 1            1042            34.4  ...       B              NO
# 2            1010            22.2  ...       A              NO
# 3            1009            39.9  ...       A              SI
# 4            1008            51.7  ...       A              NO
# 5            1007            57.2  ...       A              NO
# 6            1006            43.7  ...       A              NO
# 7            1005            72.3  ...       A              SI
# 8            1004            78.2  ...       A              NO
# 9            1003            13.9  ...       A              NO
# 10           1002            57.9  ...       A              SI
# 11           1001            55.8  ...       A              SI
# 12           1031            64.9  ...       B              NO
# 13           1029            17.4  ...       B              SI
# ...

# %%
df = pd.read_excel('/content/drive/My Drive/RegresionMultiple/Prob_Reg_Mul.xlsx', header=None, skiprows=1)
print(df)
# Out:
#        0     1     2      3     4  5   6
# 0   1044  73.8  50.5  704.1 -40.9  B  SI
# 1   1042  34.4  24.2  179.9  12.3  B  NO
# 2   1010  22.2  33.5   61.5 -32.7  A  NO
# 3   1009  39.9  38.5   86.4 -13.5  A  SI
# 4   1008  51.7  26.2   42.4 -31.9  A  NO
# 5   1007  57.2  27.2   61.2 -17.6  A  NO
# 6   1006  43.7  29.4   54.0 -10.0  A  NO
# 7   1005  72.3  26.0   77.5 -21.6  A  SI
# 8   1004  78.2  18.4   86.6 -12.8  A  NO
# 9   1003  13.9  22.5   38.3 -33.6  A  NO
# 10  1002  57.9  26.2  111.0 -22.6  A  SI
# 11  1001  55.8  28.7   52.6  -2.9  A  SI
# 12  1031  64.9  21.7  139.9 -35.0  B  NO
# 13  1029  17.4  14.7  132.1  -8.1  B  SI
# 14  1028  29.0  29.3   62.6 -10.3  B  SI
# 15  1027  83.5  26.0  154.2 -15.8  B  NO
# 16  1026  19.5  28.3   63.5   2.2  B  NO
# 17  1023  41.4  27.6   70.7 -38.2  A  NO
# 18  1022  68.1  25.2  105.2 -35.7  A  NO
# 19  1021  14.2  29.4   35.2 -13.9  A  NO
# 20  1020   5.7  31.3   38.6  27.2  A  NO
# 21  1019  18.7  23.7   32.0  -0.6  A  NO
# ...

# %%
X=df[['x1','x2','x3','x4']] 
print(X)
Y=df['y']
print(Y)

# %%
p_entrada=0.8
X_entrada=X[:int(0.8*len(X))] 
X_valida=X[int(0.8*len(X)):]
print(X_entrada)
print(X_valida)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e8d692f51fde> in <module>()
#       1 p_entrada=0.8
# ----> 2 X_entrada=X[:int(0.8*len(X))]
#       3 X_valida=X[int(0.8*len(X)):]
#       4 print(X_entrada)
#       5 print(X_valida)
#
# NameError: name 'X' is not defined

# %%
from sklearn.model_selection import train_test_split
X_entrada, X_valida, Y_entrada, Y_valida = train_test_split(X,Y, test_size=0.2) 
print(X_entrada)
print(X_valida)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6d3a7a3d8a9c> in <module>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_entrada, X_valida, Y_entrada, Y_valida = train_test_split(X,Y, test_size=0.2)
#       3 print(X_entrada)
#       4 print(X_valida)
#
# NameError: name 'X' is not defined
