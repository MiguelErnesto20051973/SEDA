# %%
import pygame
import pyworld as pw
from gtts import gTTS
from tempfile import TemporaryFile
from pygame import mixer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-79b8621c9a2a> in <module>()
# ----> 1 import pygame
#       2 import pyworld as pw
#       3 from gtts import gTTS
#       4 from tempfile import TemporaryFile
#       5 from pygame import mixer
#
# ModuleNotFoundError: No module named 'pygame'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
tts = gTTS(text='Hola ¿Cómo estás?', lang='es')
ficheroMP3='C:\\IA\\tts.mp3'
tts.save(ficheroMP3)

# %%
mixer.init()
mixer.music.load(ficheroMP3)
print("Reproduciendo {0}".format(ficheroMP3))
mixer.music.play()
while mixer.music.get_busy(): 
    pygame.time.Clock().tick(10)
mixer.quit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dd4047feec02> in <module>()
# ----> 1 mixer.init()
#       2 mixer.music.load(ficheroMP3)
#       3 print("Reproduciendo {0}".format(ficheroMP3))
#       4 mixer.music.play()
#       5 while mixer.music.get_busy():
#
# NameError: name 'mixer' is not defined

# %%
pip install pygame

# %%
pip install pyworld

# %%
pip install gtts

# %%
pip install pygame

# %%
pip install mixer

# %%
pip install tempfile
